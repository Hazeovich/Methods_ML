# %%
import pandas as pd

def get_busiest_states(data: pd.DataFrame) -> pd.Series:
    """
    Вычисляет Series, в котором индексы - наименования штатов, а значение - количество совершённых международных звонов. 

    Параметры:
      data: DataFrame с данными

    Возвращаемое значение:
      Series отсортированный по убыванию значений.
    """
    return data.groupby('State')['Total intl calls'].sum().sort_values(ascending=False, inplace=True)

# %%
head = "State,Account length,Area code,International plan,Voice mail plan,Number vmail messages,Total day minutes,Total day calls,Total day charge,Total eve minutes,Total eve calls,Total eve charge,Total night minutes,Total night calls,Total night charge,Total intl minutes,Total intl calls,Total intl charge,Customer service calls,Churn"
a1 = ["KS",128,415,"No","Yes",25,265.1,110,45.07,197.4,99,16.78,244.7,91,11.01,10,3,2.7,1,False]
a2 = ["KS",107,415,"No","Yes",26,161.6,123,27.47,195.5,103,16.62,254.4,103,11.45,13.7,3,3.7,1,False]
a3 = ["OH",137,415,"No","No",0,243.4,114,41.38,121.2,110,10.3,162.6,104,7.32,12.2,5,3.29,0,False]
a4 = ["OH",84,408,"Yes","No",0,299.4,71,50.9,61.9,88,5.26,196.9,89,8.86,6.6,7,1.78,2,False]

# %%
head = head.split(",")
head
# Out:
# ['State',
#  'Account length',
#  'Area code',
#  'International plan',
#  'Voice mail plan',
#  'Number vmail messages',
#  'Total day minutes',
#  'Total day calls',
#  'Total day charge',
#  'Total eve minutes',
#  'Total eve calls',
#  'Total eve charge',
#  'Total night minutes',
#  'Total night calls',
#  'Total night charge',
#  'Total intl minutes',
#  'Total intl calls',
#  'Total intl charge',
#  'Customer service calls',
#  'Churn']

# %%
df = pd.DataFrame([a1,a2,a3,a4], columns=head)
df
# Out:
#   State  Account length  Area code International plan Voice mail plan
# 0    KS             128        415                 No             Yes  \
# 1    KS             107        415                 No             Yes
# 2    OH             137        415                 No              No
# 3    OH              84        408                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls
# 0                     25              265.1              110  \
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge
# 0             45.07              197.4               99             16.78  \
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
# ...

# %%
import pandas as pd
def get_busiest_states(data: pd.DataFrame) -> pd.Series:
    """
    Вычисляет Series, в котором индексы - наименования штатов, а значение - количество совершённых международных звонов. 

    Параметры:
      data: DataFrame с данными

    Возвращаемое значение:
      Series отсортированный по убыванию значений.
    """
    return data[['State', 'Total intl calls']].groupby('State')['Total intl calls'].sum().sort_values(ascending=False)

# %%
get_busiest_states(df)
# Out:
# State
# OH    12
# KS     6
# Name: Total intl calls, dtype: int64
